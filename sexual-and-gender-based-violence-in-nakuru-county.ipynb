# %% [markdown]
# <a href="https://www.kaggle.com/code/kennethnjuguna/sexual-and-gender-based-violence-in-nakuru-county?scriptVersionId=133395309" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sexual-and-gender-violence-in-nakuru-county/sexual_and_gender_based_violence_cases_from_january_2014_to_september_2016_in_nakuru_county.csv

# %% [markdown]
# **Import the needed libraries to work with the dataset**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Import the dataset Sexual and Gender based violence in Nakuru County**

# %%
df=pd.read_csv("/kaggle/input/sexual-and-gender-violence-in-nakuru-county/sexual_and_gender_based_violence_cases_from_january_2014_to_september_2016_in_nakuru_county.csv")

# %% [markdown]
# **Check the dataset details using the df.head function**

# %%
df.head()
# Out:
#   Year/Month  No_of_rape_survivors  Total_survivors_with_disability  \
# 0     Jan-14                    63                                3
# 1     Feb-14                    45                                4
# 2     Mar-14                    67                                0
# 3     Apr-14                    50                                3
# 4     May-14                    54                                3
#
#    No_of_perpetrators  OBJECTID
# 0                  11         0
# 1                   5         1
# 2                   5         2
# 3                   0         3
# 4                   3         4

# %% [markdown]
# **Know the datatypes**

# %%
df.dtypes
# Out:
# Year/Month                         object
# No_of_rape_survivors                int64
# Total_survivors_with_disability     int64
# No_of_perpetrators                  int64
# OBJECTID                            int64
# dtype: object

# %% [markdown]
# * By running the dtypes function we realise what each column data type is. i.e for our dataset which has five columns we have 1 column= Object and the rest are int64 datatype.

# %% [markdown]
# **Detailed data information**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33 entries, 0 to 32
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Year/Month                       33 non-null     object
#  1   No_of_rape_survivors             33 non-null     int64
#  2   Total_survivors_with_disability  33 non-null     int64
#  3   No_of_perpetrators               33 non-null     int64
#  4   OBJECTID                         33 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 1.4+ KB

# %% [markdown]
# **Check the last columns of the dataset**

# %%
df.tail()
# Out:
#    Year/Month  No_of_rape_survivors  Total_survivors_with_disability  \
# 28     May-16                   136                                3
# 29     Jun-16                   114                                3
# 30     Jul-16                   154                                4
# 31     Aug-16                   141                               11
# 32     Sep-16                   134                                2
#
#     No_of_perpetrators  OBJECTID
# 28                   1        28
# 29                   2        29
# 30                  10        30
# 31                   3        31
# 32                  13        32

# %% [markdown]
# **Find duplicate values within the dataset**

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# * Analysis by the duplicate function proves that there is no duplicate values within the whole dataset.
# * By having no duplicate values is very important for us to know.

# %% [markdown]
# **Check for missing data as seeing below the dataset has no missing values**

# %%
missing_data= df.isnull()
missing_data.head(5)
# Out:
#    Year/Month  No_of_rape_survivors  Total_survivors_with_disability  \
# 0       False                 False                            False
# 1       False                 False                            False
# 2       False                 False                            False
# 3       False                 False                            False
# 4       False                 False                            False
#
#    No_of_perpetrators  OBJECTID
# 0               False     False
# 1               False     False
# 2               False     False
# 3               False     False
# 4               False     False

# %% [markdown]
# * In EDA it is very important to know if we have missing values so we can replace them with the mean of that column.

# %% [markdown]
# **Visualize the data**

# %% [markdown]
# **Visualize correlation plot of the whole dataset**

# %%
sns.heatmap(df.corr())
# Out:
# /tmp/ipykernel_32/58359773.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr())
# <Axes: >

# %% [markdown]
# **Do a barplot of data for the number of Perpetrators in relation to date and Month**

# %%
sns.barplot(data=df, x="No_of_perpetrators", y="Year/Month")
# Out:
# <Axes: xlabel='No_of_perpetrators', ylabel='Year/Month'>

# %% [markdown]
# **Lets Analyse the above bar chart On No of Perpetrators**
# * The highest Number of Perpetrators happened on December 15th.
# * The lowest Number of Perpetrators happened on May 16th.
# * On April 14th there were 0 Number of perpetrators.

# %% [markdown]
# **Do a bar plot for the number of rape survivors within each date of the month**

# %%
sns.barplot(data=df,x ='No_of_rape_survivors',y='Year/Month' )
# Out:
# <Axes: xlabel='No_of_rape_survivors', ylabel='Year/Month'>

# %% [markdown]
# **From the above analysis we have found out that on Number of Rape Survivors on the following dates:-**
# * The day with most Number of Rape survivors as seen above is on September 15.
# * The least Number of rape survivors happened on February 14th.

# %% [markdown]
# **Do a bar plot of Total survivors with disability**

# %%
sns.barplot(data=df, x="Total_survivors_with_disability", y="Year/Month")
# Out:
# <Axes: xlabel='Total_survivors_with_disability', ylabel='Year/Month'>

# %% [markdown]
# **From the above bar chart on Total Survivors with disability we have analysed that:-**
# * The highest number of total survivors with disability happened on August 16th.
# * The lowest number of total survivors with disability happened on Septemeber 15th.
# * There were no survivors with diability on March 14th and August 14th.

# %% [markdown]
# **Do a pie chart of the Number of perpetrators**

# %%
df['OBJECTID'].value_counts().plot.pie(figsize=(8,8),autopct='%.2f')
plt.title('Gender based violence in Nakuru County')
# Out:
# Text(0.5, 1.0, 'Gender based violence in Nakuru County')

# %% [markdown]
# **Plot Jointplot with all the data**

# %%
sns.jointplot(data=df, x="No_of_perpetrators", y="No_of_rape_survivors")

# %% [markdown]
# **Joint plot with the hist kind**

# %%
sns.jointplot(data=df, x="No_of_perpetrators", y="No_of_rape_survivors",kind="hist")

# %% [markdown]
# **Histplot of the data Number of perpetrators**

# %%
sns.histplot(data=df, y="No_of_perpetrators")
# Out:
# <Axes: xlabel='Count', ylabel='No_of_perpetrators'>

# %% [markdown]
# **Flip the histogram above**

# %%
sns.histplot(data=df, x="No_of_perpetrators")
# Out:
# <Axes: xlabel='No_of_perpetrators', ylabel='Count'>

# %% [markdown]
# **Add bins to the histogram**

# %%
sns.histplot(data=df, x="No_of_perpetrators", bins=20)
# Out:
# <Axes: xlabel='No_of_perpetrators', ylabel='Count'>

# %% [markdown]
# **Do a histogram of Number of rape survivors within every month**

# %%
sns.histplot(data=df, x="No_of_rape_survivors",y="No_of_perpetrators", hue="Year/Month")
# Out:
# <Axes: xlabel='No_of_rape_survivors', ylabel='No_of_perpetrators'>

# %% [markdown]
# **Do a bar chart for each month**

# %%
df.No_of_rape_survivors.value_counts().nlargest(10).plot(kind='bar',figsize=(15,5))
plt.title("No of Rape Survivors by Month")
plt.ylabel("Year/Month")
plt.xlabel("No of  Rape Survivors")
# Out:
# Text(0.5, 0, 'No of  Rape Survivors')
