# %% [markdown]
# <a href="https://www.kaggle.com/code/kennethnjuguna/sexual-and-gender-based-violence-in-nakuru-county?scriptVersionId=132706451" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# **Import the needed libraries to work with the dataset**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Import the dataset Sexual and Gender based violence in Nakuru County**

# %%
df=pd.read_csv("/kaggle/input/sexual-and-gender-violence-in-nakuru-county/sexual_and_gender_based_violence_cases_from_january_2014_to_september_2016_in_nakuru_county.csv")

# %% [markdown]
# **Check the dataset details using the df.head function**

# %%
df.head()

# %% [markdown]
# **Know the datatypes**

# %%
df.dtypes

# %% [markdown]
# **Detailed data information**

# %%
df.info()

# %% [markdown]
# **Check the last columns of the dataset**

# %%
df.tail()

# %% [markdown]
# **Find duplicate values within the dataset**

# %%
df.duplicated().sum()

# %% [markdown]
# **Check for missing data as seeing below the dataset has no missing values**

# %%
missing_data= df.isnull()
missing_data.head(32)

# %% [markdown]
# **Visualize the data**

# %% [markdown]
# **Visualize correlation plot of the whole dataset**

# %%
sns.heatmap(df.corr())

# %% [markdown]
# **Do a pie chart of the data in relation between No of rape survivors, Total number of survivors with disability and Number of perpetrators**

# %%
df['No_of_perpetrators'].value_counts().plot.pie(figsize=(8,8),autopct='%.2f')

# %% [markdown]
# **Plot a piechart with all the data**

# %%
#define all the data
data=['No_of_rape_survivors','Total_survivors_with_disability','No_of_perpetrators']
labels=['No_of_rape_survivors','Total_survivors_with_disability','No_of_perpetrators']

#define seaborn color palettes to use
colors=sns.color_palette('pastel')[0:6]

#create pie chart
plt.pie(data,labels=labels,colors=colors, autopct='%.0f%%')
plt.show()
